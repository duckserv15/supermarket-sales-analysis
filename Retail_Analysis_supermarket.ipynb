# %% [markdown]
# # Data Analysis with Python - Part 1

# %% [markdown]
# ## Introduction

# %% [markdown]
# The objective of this notebook is to use the simple functions in Pandas to analyze the grocery sales dataset and then visualize it using Seaborn. Apart from deriving some summary metrics, we'll also frame some questions and find answers from the dataset by delving into it. This will be a very good practise for data analytics enthusiasts.

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# * Importing Libraries and Dataset
# * Data Manipulation
# * Preparing Summary Metrics
# * Answering the Questions
# * Conclusion

# %% [markdown]
# ## Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Let us read the input dataset and store it in a dataframe. After loading it, we'll take a look at any 5 rows from the dataframe to understand the data. We'll use sample() to extract few samples out of the dataframe.
#
# Alternatively, you can use .head() or .tail() functions to extract the first N or the last N rows respectively.

# %%
df_central = pd.read_csv('./Supermart Grocery Sales Central Region.csv')
df_central
# Out:
#      Order ID Customer Name      Category       Sub Category         City  \
# 0        OD15        Sundar           NaN            Chicken  Kanyakumari
# 1        OD16        Ramesh  Oil & Masala  Edible Oil & Ghee  Krishnagiri
# 2        OD17          Alan        Bakery              Cakes   Dharmapuri
# 3        OD22          Alan   Food Grains      Dals & Pulses        Karur
# 4         NaN       Haseena           NaN                NaN  Krishnagiri
# ...       ...           ...           ...                ...          ...
# 1821   OD9855         Kumar        Snacks            Noodles   Viluppuram
# 1822   OD9856         James           NaN     Organic Fruits          NaN
# 1823   OD9857         Yusuf  Oil & Masala            Masalas   Pudukottai
# 1824   OD9859         Shree   Food Grains               Rice   Perambalur
# 1825   OD9860       Hussain           NaN    Organic Staples          NaN
#
#       Order Date   Region   Sales  Discount  Profit       State
# 0            NaN  Central   831.0      0.22  207.75  Tamil Nadu
# 1     11/22/2016  Central  1440.0      0.11  100.80         NaN
# 2     11-11-2015  Central  1678.0      0.28  318.82         NaN
# 3            NaN  Central   948.0      0.13   47.40  Tamil Nadu
# 4     12-09-2017  Central     NaN       NaN  148.47  Tamil Nadu
# ...          ...      ...     ...       ...     ...         ...
# 1821         NaN  Central  1292.0      0.34  348.84  Tamil Nadu
# 1822         NaN  Central  1168.0      0.19     NaN  Tamil Nadu
# 1823  03-08-2017  Central  2322.0      0.10  348.30  Tamil Nadu
# 1824         NaN  Central  1448.0      0.15     NaN  Tamil Nadu
# 1825  10-12-2018  Central  1824.0      0.13  200.64  Tamil Nadu
#
# [1826 rows x 11 columns]

# %%
df_east = pd.read_csv('./Supermart Grocery Sales East Region.csv')
df_east
# Out:
#      Order ID Customer Name           Category        Sub Category  \
# 0         NaN      Veronica          Beverages         Soft Drinks
# 1        OD30           NaN       Oil & Masala             Masalas
# 2        OD31        Ramesh          Beverages         Soft Drinks
# 3         NaN           NaN             Snacks                 NaN
# 4        OD33         Akash                NaN                 NaN
# ...       ...           ...                ...                 ...
# 2274      NaN        Ganesh   Fruits & Veggies  Organic Vegetables
# 2275   OD9909       Hussain       Oil & Masala             Masalas
# 2276   OD9910        Amrish             Bakery       Breads & Buns
# 2277   OD9911         Akash  Eggs, Meat & Fish              Mutton
# 2278   OD9912         Yusuf       Oil & Masala              Spices
#
#              City  Order Date Region   Sales  Discount   Profit       State
# 0     Krishnagiri         NaN   East  1988.0       NaN   874.72         NaN
# 1     Kanyakumari   9/17/2016   East   989.0      0.17    69.23  Tamil Nadu
# 2      Dharmapuri   9/17/2016   East     NaN      0.24   166.05  Tamil Nadu
# 3         Vellore   9/17/2016   East  1400.0       NaN   420.00  Tamil Nadu
# 4          Trichy         NaN   East  2163.0      0.26   670.53  Tamil Nadu
# ...           ...         ...    ...     ...       ...      ...         ...
# 2274   Coimbatore  12/23/2017   East   872.0      0.18   148.24  Tamil Nadu
# 2275          NaN         NaN   East  1652.0       NaN   479.08  Tamil Nadu
# 2276   Viluppuram   7/21/2018   East   920.0      0.14   220.80  Tamil Nadu
# 2277       Cumbum  11-10-2017   East  1847.0      0.26   591.04  Tamil Nadu
# 2278          NaN  12-01-2018   East  2447.0       NaN  1052.21  Tamil Nadu
#
# [2279 rows x 11 columns]

# %%
df_west = pd.read_csv('./Supermart Grocery Sales West Region.csv')
df_west
# Out:
#      Order ID Customer Name           Category     Sub Category         City  \
# 0         NaN       Hussain        Food Grains     Atta & Flour   Perambalur
# 1         OD6        Adavan        Food Grains  Organic Staples   Dharmapuri
# 2         OD9         Hafiz             Bakery         Biscuits  Tirunelveli
# 3        OD10           NaN                NaN            Cakes      Chennai
# 4        OD11        Ganesh                NaN       Chocolates        Karur
# ...       ...           ...                ...              ...          ...
# 2561   OD9989       Jackson             Snacks              NaN      Vellore
# 2562   OD9990        Sudeep  Eggs, Meat & Fish              NaN          NaN
# 2563      NaN          Alan             Bakery         Biscuits  Kanyakumari
# 2564   OD9993          Peer       Oil & Masala           Spices          NaN
# 2565      NaN        Ganesh                NaN     Atta & Flour  Tirunelveli
#
#       Order Date Region   Sales  Discount  Profit       State
# 0     06-12-2017   West  2360.0      0.21  165.20  Tamil Nadu
# 1     06-09-2015   West  2305.0      0.26     NaN  Tamil Nadu
# 2     06-09-2015   West   791.0      0.23     NaN  Tamil Nadu
# 3     06-09-2015   West     NaN      0.27  484.65         NaN
# 4     06-09-2015   West  1903.0      0.13     NaN         NaN
# ...          ...    ...     ...       ...     ...         ...
# 2561  11-03-2016   West  1460.0      0.15  452.60  Tamil Nadu
# 2562  12/24/2015   West   945.0      0.16  359.10  Tamil Nadu
# 2563  07-12-2015   West     NaN      0.26     NaN  Tamil Nadu
# 2564  10/16/2018   West     NaN      0.15  597.24  Tamil Nadu
# 2565   4/17/2018   West     NaN      0.28  165.44  Tamil Nadu
#
# [2566 rows x 11 columns]

# %%
df_south = pd.read_csv('./Supermart Grocery Sales South Region.csv')
df_south
# Out:
#      Order ID Customer Name          Category      Sub Category         City  \
# 0         OD2         Sudha         Beverages     Health Drinks  Krishnagiri
# 1         OD4       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 2         OD5           NaN       Food Grains   Organic Staples          NaN
# 3         NaN           NaN      Oil & Masala           Masalas         Ooty
# 4        OD73          Alan            Snacks           Cookies        Theni
# ...       ...           ...               ...               ...          ...
# 1267      NaN         Jonas         Beverages     Health Drinks   Viluppuram
# 1268   OD9936           NaN            Snacks           Noodles          NaN
# 1269   OD9940        Adavan            Snacks        Chocolates         Bodi
# 1270   OD9941           NaN         Beverages       Soft Drinks          NaN
# 1271   OD9942        Amrish            Snacks           Cookies          NaN
#
#       Order Date Region   Sales  Discount  Profit       State
# 0     11-08-2017  South   749.0       NaN  149.80  Tamil Nadu
# 1     10-11-2016  South   896.0       NaN     NaN  Tamil Nadu
# 2     10-11-2016  South  2355.0       NaN  918.45  Tamil Nadu
# 3     06-04-2017  South  1232.0      0.14  554.40  Tamil Nadu
# 4            NaN  South   721.0      0.27     NaN  Tamil Nadu
# ...          ...    ...     ...       ...     ...         ...
# 1267  05-05-2017  South  1141.0      0.12   68.46         NaN
# 1268  10/24/2017  South  1411.0      0.16  395.08  Tamil Nadu
# 1269  11-02-2015  South     NaN      0.15  624.00  Tamil Nadu
# 1270   3/18/2015  South  2379.0      0.23  428.22         NaN
# 1271   3/18/2015  South  1843.0      0.21  829.35  Tamil Nadu
#
# [1272 rows x 11 columns]

# %%
df = pd.concat([df_east,df_central,df_west,df_south], ignore_index=True)
df.sample(5)
# Out:
#      Order ID Customer Name          Category   Sub Category         City  \
# 5804   OD6819           NaN      Oil & Masala            NaN       Trichy
# 3752   OD7985         Yusuf  Fruits & Veggies   Fresh Fruits       Trichy
# 6907   OD1798        Roshan            Bakery  Breads & Buns          NaN
# 3587   OD6937         James               NaN            NaN  Tirunelveli
# 6380   OD8894         Yusuf  Fruits & Veggies   Fresh Fruits       Cumbum
#
#       Order Date   Region   Sales  Discount  Profit       State
# 5804  03-12-2017     West   830.0      0.10  348.60         NaN
# 3752         NaN  Central  2331.0      0.16  116.55  Tamil Nadu
# 6907  05-01-2018    South  1341.0       NaN  482.76         NaN
# 3587  11/24/2015  Central  2462.0      0.23  837.08         NaN
# 6380  11-06-2018     West   958.0      0.34  249.08         NaN

# %%
df.head(5)
# Out:
#   Order ID Customer Name      Category Sub Category         City Order Date  \
# 0      NaN      Veronica     Beverages  Soft Drinks  Krishnagiri        NaN
# 1     OD30           NaN  Oil & Masala      Masalas  Kanyakumari  9/17/2016
# 2     OD31        Ramesh     Beverages  Soft Drinks   Dharmapuri  9/17/2016
# 3      NaN           NaN        Snacks          NaN      Vellore  9/17/2016
# 4     OD33         Akash           NaN          NaN       Trichy        NaN
#
#   Region   Sales  Discount  Profit       State
# 0   East  1988.0       NaN  874.72         NaN
# 1   East   989.0      0.17   69.23  Tamil Nadu
# 2   East     NaN      0.24  166.05  Tamil Nadu
# 3   East  1400.0       NaN  420.00  Tamil Nadu
# 4   East  2163.0      0.26  670.53  Tamil Nadu

# %%
df.tail(5)
# Out:
#      Order ID Customer Name   Category   Sub Category        City  Order Date  \
# 7938      NaN         Jonas  Beverages  Health Drinks  Viluppuram  05-05-2017
# 7939   OD9936           NaN     Snacks        Noodles         NaN  10/24/2017
# 7940   OD9940        Adavan     Snacks     Chocolates        Bodi  11-02-2015
# 7941   OD9941           NaN  Beverages    Soft Drinks         NaN   3/18/2015
# 7942   OD9942        Amrish     Snacks        Cookies         NaN   3/18/2015
#
#      Region   Sales  Discount  Profit       State
# 7938  South  1141.0      0.12   68.46         NaN
# 7939  South  1411.0      0.16  395.08  Tamil Nadu
# 7940  South     NaN      0.15  624.00  Tamil Nadu
# 7941  South  2379.0      0.23  428.22         NaN
# 7942  South  1843.0      0.21  829.35  Tamil Nadu

# %% [markdown]
# Let us quickly check the information about the dataset.

# %% [markdown]
# ##Examining The Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7943 entries, 0 to 7942
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       6342 non-null   object
#  1   Customer Name  6348 non-null   object
#  2   Category       6404 non-null   object
#  3   Sub Category   6404 non-null   object
#  4   City           6322 non-null   object
#  5   Order Date     6373 non-null   object
#  6   Region         7943 non-null   object
#  7   Sales          6341 non-null   float64
#  8   Discount       6334 non-null   float64
#  9   Profit         6357 non-null   float64
#  10  State          6364 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 682.7+ KB

# %%
df.isnull().sum()
# Out:
# Order ID         1601
# Customer Name    1595
# Category         1539
# Sub Category     1539
# City             1621
# Order Date       1570
# Region              0
# Sales            1602
# Discount         1609
# Profit           1586
# State            1579
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]
# Out:
# Order ID         0.201561
# Customer Name    0.200806
# Category         0.193756
# Sub Category     0.193756
# City             0.204079
# Order Date       0.197658
# Region           0.000000
# Sales            0.201687
# Discount         0.202568
# Profit           0.199673
# State            0.198791
# dtype: float64

# %%
(df.isnull().sum()/df.shape[0]).round(2)
# Out:
# Order ID         0.20
# Customer Name    0.20
# Category         0.19
# Sub Category     0.19
# City             0.20
# Order Date       0.20
# Region           0.00
# Sales            0.20
# Discount         0.20
# Profit           0.20
# State            0.20
# dtype: float64

# %%
df.describe()
# Out:
#              Sales     Discount       Profit
# count  6341.000000  6334.000000  6357.000000
# mean   1498.946381     0.227024   376.365863
# std     580.331820     0.074509   240.521891
# min     500.000000     0.100000    25.450000
# 25%    1000.000000     0.160000   180.360000
# 50%    1500.000000     0.230000   323.380000
# 75%    2005.000000     0.290000   530.040000
# max    2500.000000     0.350000  1120.950000

# %%
df.describe(include='object')
# Out:
#        Order ID Customer Name Category Sub Category         City  Order Date  \
# count      6342          6348     6404         6404         6322        6373
# unique     6342            50        7           23           24        1164
# top        OD30        Amrish   Snacks  Soft Drinks  Kanyakumari  12-01-2018
# freq          1           149      966          457          299          25
#
#        Region       State
# count    7943        6364
# unique      4           1
# top      West  Tamil Nadu
# freq     2566        6364

# %% [markdown]
# We'll take a look at the Region column to understand the spread of different categories.

# %% [markdown]
# ##Data Cleaning

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='Sales', data=df)
plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(2,1,1)
sns.boxplot(x='Sales', data=df)

plt.subplot(2,1,2)
sns.boxplot(x='Discount', data=df)

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
sns.boxplot(x='Sales', data=df)

plt.subplot(1,3,2)
sns.boxplot(x='Discount', data=df)

plt.subplot(1,3,3)
sns.boxplot(x='Profit', data=df)

plt.show()

# %%
#Jika numerik dengan outlier -> Median
#Jika numerik tanpa outlier -> Mean
#Jika kategorikal -> Modus

df['Sales'] = df['Sales'].fillna(df['Sales'].mean())
df['Discount'] = df['Discount'].fillna(df['Discount'].mean())
df['Profit'] = df['Profit'].fillna(df['Profit'].median())

print(df[['Sales','Discount','Profit']].isnull().sum())
# Out:
# Sales       0
# Discount    0
# Profit      0
# dtype: int64

# %%
#Order ID tidak boleh duplikat karena bersifat unique,
#jadi kita tidak dapat mengisi nya dengan modus, oleh karena itu maka akan kita buang yang kosong
#Begitu pula dengan nama dan juga date

df.dropna(subset=['Order ID','Order Date'], inplace=True)
df['Customer Name'] = df['Customer Name'].fillna('Customer')
df['City'] = df['City'].fillna(df['City'].mode()[0])

df[['Order ID','Customer Name','Order Date','City']].isnull().sum()
# Out:
# Order ID         0
# Customer Name    0
# Order Date       0
# City             0
# dtype: int64

# %%
df.dropna(subset=['Category','Sub Category'], how='all', inplace=True)
df[['Category','Sub Category']].isnull().sum()
# Out:
# Category        796
# Sub Category    788
# dtype: int64

# %%
category = df['Category'].value_counts().index.values
category
# Out:
# array(['Eggs, Meat & Fish', 'Snacks', 'Food Grains', 'Fruits & Veggies',
#        'Bakery', 'Beverages', 'Oil & Masala'], dtype=object)

# %%
isian_sub = {'Eggs, Meat & Fish' : df[df['Category']=='Eggs, Meat & Fish']['Sub Category'].mode()[0],
             'Snacks' : df[df['Category']=='Snacks']['Sub Category'].mode()[0],
             'Food Grains' : df[df['Category']=='Food Grains']['Sub Category'].mode()[0],
             'Fruits & Veggies' : df[df['Category']=='Fruits & Veggies']['Sub Category'].mode()[0],
             'Bakery' : df[df['Category']=='Bakery']['Sub Category'].mode()[0],
             'Beverages' : df[df['Category']=='Beverages']['Sub Category'].mode()[0],
             'Oil & Masala' : df[df['Category']=='Oil & Masala']['Sub Category'].mode()[0]}

# %%
print(isian_sub)
# Out:
# {'Eggs, Meat & Fish': 'Mutton', 'Snacks': 'Noodles', 'Food Grains': 'Dals & Pulses', 'Fruits & Veggies': 'Fresh Vegetables', 'Bakery': 'Breads & Buns', 'Beverages': 'Soft Drinks', 'Oil & Masala': 'Masalas'}

# %%
def change_sub(cat,sub_cat,category, isian_sub):

  for i in category: #melakukan iterasi pada setiap kategori

    if (cat==i): #Jika kategori = i
      if(sub_cat != sub_cat): #Jika di kategori i sub kategori nya nan
        return isian_sub[i] #diisi dengan modus pada kategori tersebut
      else:
        return str(sub_cat) #jika tidak kosong, isi dengan nilai aslinya

    elif(cat != cat): #Untuk tetap mendapatkan sub kategori dari yg kolom kategori = nan
      return str(sub_cat)

# %%
df[df['Sub Category'].isnull()].head(5)
# Out:
#    Order ID Customer Name           Category Sub Category            City  \
# 16    OD114      Customer   Fruits & Veggies          NaN     Krishnagiri
# 24    OD132      Customer          Beverages          NaN       Nagercoil
# 56    OD277          Shah  Eggs, Meat & Fish          NaN  Ramanadhapuram
# 57    OD278           Ram       Oil & Masala          NaN    Virudhunagar
# 72    OD321          Alan   Fruits & Veggies          NaN      Dharmapuri
#
#     Order Date Region   Sales  Discount  Profit       State
# 16   8/25/2015   East  1154.0  0.100000  323.38  Tamil Nadu
# 24  02-02-2018   East  2112.0  0.227024  323.38  Tamil Nadu
# 56  10/13/2018   East   812.0  0.170000  323.38  Tamil Nadu
# 57  10/13/2018   East   862.0  0.227024  137.92  Tamil Nadu
# 72  11-04-2015   East  1771.0  0.280000  602.14  Tamil Nadu

# %%
df['Sub Category'] = df.apply(lambda x: change_sub(x['Category'],x['Sub Category'], category, isian_sub), axis=1)

# %%
df.loc[[16,24,56,57,72]]
# Out:
#    Order ID Customer Name           Category      Sub Category  \
# 16    OD114      Customer   Fruits & Veggies  Fresh Vegetables
# 24    OD132      Customer          Beverages       Soft Drinks
# 56    OD277          Shah  Eggs, Meat & Fish            Mutton
# 57    OD278           Ram       Oil & Masala           Masalas
# 72    OD321          Alan   Fruits & Veggies  Fresh Vegetables
#
#               City  Order Date Region   Sales  Discount  Profit       State
# 16     Krishnagiri   8/25/2015   East  1154.0  0.100000  323.38  Tamil Nadu
# 24       Nagercoil  02-02-2018   East  2112.0  0.227024  323.38  Tamil Nadu
# 56  Ramanadhapuram  10/13/2018   East   812.0  0.170000  323.38  Tamil Nadu
# 57    Virudhunagar  10/13/2018   East   862.0  0.227024  137.92  Tamil Nadu
# 72      Dharmapuri  11-04-2015   East  1771.0  0.280000  602.14  Tamil Nadu

# %%
isian_cat = {'Eggs, Meat & Fish' : df[df['Category']=='Eggs, Meat & Fish']['Sub Category'].unique(),
             'Snacks' : df[df['Category']=='Snacks']['Sub Category'].unique(),
             'Food Grains' : df[df['Category']=='Food Grains']['Sub Category'].unique(),
             'Fruits & Veggies' : df[df['Category']=='Fruits & Veggies']['Sub Category'].unique(),
             'Bakery' : df[df['Category']=='Bakery']['Sub Category'].unique(),
             'Beverages' : df[df['Category']=='Beverages']['Sub Category'].unique(),
             'Oil & Masala' : df[df['Category']=='Oil & Masala']['Sub Category'].unique()}

# %%
isian_cat
# Out:
# {'Eggs, Meat & Fish': array(['Mutton', 'Fish', 'Chicken', 'Eggs'], dtype=object),
#  'Snacks': array(['Noodles', 'Chocolates', 'Cookies'], dtype=object),
#  'Food Grains': array(['Dals & Pulses', 'Atta & Flour', 'Organic Staples', 'Rice'],
#        dtype=object),
#  'Fruits & Veggies': array(['Fresh Vegetables', 'Organic Fruits', 'Fresh Fruits',
#         'Organic Vegetables'], dtype=object),
#  'Bakery': array(['Cakes', 'Breads & Buns', 'Biscuits'], dtype=object),
#  'Beverages': array(['Soft Drinks', 'Health Drinks'], dtype=object),
#  'Oil & Masala': array(['Masalas', 'Edible Oil & Ghee', 'Spices'], dtype=object)}

# %%
value = 'Mutton'
# Get list of keys that contains the given value
keys = [key for key, list_of_values in isian_cat.items() if value in list_of_values]

print(keys[0])
# Out:
# Eggs, Meat & Fish

# %%
def change_cat(cat,sub_cat, isian_cat):

  if(cat != cat):
    keys = [key for key, list_of_values in isian_cat.items() if sub_cat in list_of_values]
    return str(keys[0])
  else:
    return str(cat)

# %%
df[df['Category'].isnull()].head(5)
# Out:
#    Order ID Customer Name Category      Sub Category         City  Order Date  \
# 17    OD115        Muneer      NaN           Noodles        Salem   8/25/2015
# 37    OD201         James      NaN   Organic Staples  Tirunelveli   6/24/2018
# 42    OD217        Sundar      NaN              Rice  Krishnagiri  01-02-2016
# 43    OD220        Arvind      NaN  Fresh Vegetables   Pudukottai  12/24/2016
# 45    OD222       Willams      NaN              Fish      Vellore  12/24/2016
#
#    Region        Sales  Discount  Profit       State
# 17   East  2420.000000  0.110000  323.38  Tamil Nadu
# 37   East  1498.946381  0.220000  243.32  Tamil Nadu
# 42   East  1733.000000  0.227024  433.25  Tamil Nadu
# 43   East  2110.000000  0.227024  323.38  Tamil Nadu
# 45   East  1557.000000  0.227024  638.37  Tamil Nadu

# %%
df['Category'] = df.apply(lambda x: change_cat(x['Category'],x['Sub Category'], isian_cat), axis=1)

# %%
df.loc[[17,37,42,43,45]]
# Out:
#    Order ID Customer Name           Category      Sub Category         City  \
# 17    OD115        Muneer             Snacks           Noodles        Salem
# 37    OD201         James        Food Grains   Organic Staples  Tirunelveli
# 42    OD217        Sundar        Food Grains              Rice  Krishnagiri
# 43    OD220        Arvind   Fruits & Veggies  Fresh Vegetables   Pudukottai
# 45    OD222       Willams  Eggs, Meat & Fish              Fish      Vellore
#
#     Order Date Region        Sales  Discount  Profit       State
# 17   8/25/2015   East  2420.000000  0.110000  323.38  Tamil Nadu
# 37   6/24/2018   East  1498.946381  0.220000  243.32  Tamil Nadu
# 42  01-02-2016   East  1733.000000  0.227024  433.25  Tamil Nadu
# 43  12/24/2016   East  2110.000000  0.227024  323.38  Tamil Nadu
# 45  12/24/2016   East  1557.000000  0.227024  638.37  Tamil Nadu

# %%
df.isnull().sum()
# Out:
# Order ID           0
# Customer Name      0
# Category           0
# Sub Category       0
# City               0
# Order Date         0
# Region             0
# Sales              0
# Discount           0
# Profit             0
# State            960
# dtype: int64

# %%
df['State'] = df['State'].fillna('Tamil Nadu')
df.isnull().sum()
# Out:
# Order ID         0
# Customer Name    0
# Category         0
# Sub Category     0
# City             0
# Order Date       0
# Region           0
# Sales            0
# Discount         0
# Profit           0
# State            0
# dtype: int64

# %%
df.describe()
# Out:
#              Sales     Discount       Profit
# count  4907.000000  4907.000000  4907.000000
# mean   1506.945185     0.227392   367.014675
# std     520.679349     0.066119   215.892710
# min     500.000000     0.100000    27.650000
# 25%    1135.000000     0.180000   214.280000
# 50%    1498.946381     0.227024   323.380000
# 75%    1893.000000     0.270000   475.870000
# max    2500.000000     0.350000  1120.950000

# %%
df.describe(include='object')
# Out:
#        Order ID Customer Name Category Sub Category  City  Order Date Region  \
# count      4907          4907     4907         4907  4907        4907   4907
# unique     4907            51        7           23    24        1110      4
# top        OD30      Customer   Snacks  Soft Drinks  Bodi  12-08-2018   West
# freq          1           994      735          396  1209          20   1569
#
#              State
# count         4907
# unique           1
# top     Tamil Nadu
# freq          4907

# %% [markdown]
# ## Data Manipulation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4907 entries, 1 to 7942
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       4907 non-null   object
#  1   Customer Name  4907 non-null   object
#  2   Category       4907 non-null   object
#  3   Sub Category   4907 non-null   object
#  4   City           4907 non-null   object
#  5   Order Date     4907 non-null   object
#  6   Region         4907 non-null   object
#  7   Sales          4907 non-null   float64
#  8   Discount       4907 non-null   float64
#  9   Profit         4907 non-null   float64
#  10  State          4907 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 589.1+ KB

# %%
df.sample(2)
# Out:
#      Order ID Customer Name          Category  Sub Category       City  \
# 5534   OD5712        Arutra  Fruits & Veggies  Fresh Fruits       Bodi
# 1123   OD4857      Customer  Fruits & Veggies  Fresh Fruits  Nagercoil
#
#       Order Date Region        Sales  Discount  Profit       State
# 5534  09-06-2015   West  1762.000000  0.227024  176.20  Tamil Nadu
# 1123   9/16/2018   East  1498.946381  0.310000  231.88  Tamil Nadu

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

# %%
df["month"]=df["Order Date"].dt.month

# %%
df['Region'].value_counts()
# Out:
# West       1569
# East       1402
# Central    1142
# South       794
# Name: Region, dtype: int64

# %%
plt.subplot(4, 1, 1)
sns.barplot(x="Region", y="count" ,hue="month", data=Central)
plt.subplot(4, 1, 2)
sns.barplot(x="Region", y="count" ,hue="month", data=West)
plt.subplot(4, 1, 3)
sns.barplot(x="Region", y="count" ,hue="month", data=East)
plt.subplot(4, 1, 4)
sns.barplot(x="Region", y="count" ,hue="month", data=South)

# %%
plt.figure(figsize=(15,15))

plt.subplot(2, 1, 1)
sns.barplot(x="month", y="count", data=var1)
plt.subplot(2, 1, 2)
sns.barplot(x="month", y="Profit", data=df)

# %%
sns.barplot(x="month", y="Profit", data=df)

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.countplot(df['var1'],)
plt.xlabel('Region Sales', fontsize = 10)

plt.subplot(1, 2, 2)
df['Region'].value_counts().plot(kind = 'pie', explode = [0.1, 0.1, 0.1, 0.1], autopct = '%.1f%%', startangle = 90,
                                 shadow = True, pctdistance = 0.5)
plt.axis('off')

plt.suptitle('Sales Counts in Differents Region', fontsize = 15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,5))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
sns.countplot(df['Region'],)
plt.xlabel('', fontsize = 10)

plt.subplot(1, 2, 2)
df['Region'].value_counts().plot(kind = 'pie', explode = [0.1, 0.1, 0.1, 0.1], autopct = '%.2f%%', startangle = 90,
                                 shadow = True, pctdistance = 0.5)
plt.axis('off')

plt.suptitle('Sales in Different Regions', fontsize = 15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,5))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
sns.countplot(df['Region'], palette=['#4fc1e8', '#a0d568', '#ffce54','#ed5564'])
plt.xlabel('', fontsize = 10)

plt.subplot(1, 2, 2)
df['Region'].value_counts().plot(kind = 'pie', explode = [0.1, 0.1, 0.1, 0.1], autopct = '%.2f%%', startangle = 90,
                                 shadow = True, pctdistance = 0.5, colors=['#ffce54', '#4fc1e8', '#a0d568', '#ed5564'])
plt.axis('off')

plt.suptitle('Sales in Different Regions', fontsize = 15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# We'll now extract the year from the order date. The Order Date is in the string type, so let us use the string manipulation technique to do the same.

# %%
df['Order Date'].head(2)
# Out:
# 1    9/17/2016
# 2    9/17/2016
# Name: Order Date, dtype: object

# %%
df['Order Date'].values[0][:2].replace('/','')
# Out:
# '9'

# %%
df['Order Year'] = df['Order Date'].str[-4:]
df['Order Year'].value_counts()
# Out:
# 2018    1658
# 2017    1262
# 2016     997
# 2015     990
# Name: Order Year, dtype: int64

# %% [markdown]
# ## Preparing Summary Metrics

# %% [markdown]
# Let us prepare the summary metrics one by one. We'll start with the region wise analysis of sales and orders. We'll use pivot_table() function throughout this notebook. Please pay attention on how the aggfunc() could be tailored for our requirements.

# %% [markdown]
# ### Total Sales & Orders by Region

# %%
region = pd.pivot_table(data=df, index='Region', values=['Order ID', 'Sales'], 
                        aggfunc = {'Order ID':'count', 'Sales':'sum'}).reset_index().sort_values(by='Sales', ascending=False)
region
# Out:
#     Region  Order ID         Sales
# 3     West      1569  2.369521e+06
# 1     East      1402  2.097378e+06
# 0  Central      1142  1.718812e+06
# 2    South       794  1.208869e+06

# %%
plt.figure(figsize=(15,5))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
sns.barplot(x='Region', y='Sales', data=region,
            palette=['#ac92eb', '#4fc1e8', '#a0d568', '#ffce54'])
plt.xlabel('', fontsize = 10)

plt.subplot(1, 2, 2)
sns.barplot(x='Region', y='Order ID', data=region,
            palette=['#ac92eb', '#4fc1e8', '#a0d568', '#ffce54'])
plt.xlabel('', fontsize = 10)

plt.suptitle('Sales in Different Regions', fontsize = 15)
plt.show()

# %%
# fixing the graph size
plt.rcParams['figure.figsize'] = (12,6)

# setting the background color
ax = plt.axes()
ax.set_facecolor('#2F2F2f')

# plotting a bar graph
sns.barplot(y='Region', x='Sales', data=region, color='#FFCB74', linewidth=2, edgecolor='#F6F6F6')

# annotating the values on the plot
bbox_args = dict(boxstyle = 'round', fc = '1')
for p in ax.patches:
    width = p.get_width()
    plt.text(p.get_width(), p.get_y() + 0.5 * p.get_height(), '{:1.0f}'.format(width), 
             ha = 'center', 
             va = 'center', 
             color = 'black', 
             bbox = bbox_args, 
             fontsize = 15)

# formatting the graph
plt.title('Total Sales by Region', fontsize = 18)
plt.tick_params(left=False, bottom=False, labelbottom=False)
plt.ylabel(None)

plt.show()

# %%
# fixing the graph size
plt.rcParams['figure.figsize'] = (12,6)

# setting the background color
ax = plt.axes()
ax.set_facecolor('#2F2F2f')

# plotting a bar graph
sns.barplot(y='Region', x='Order ID', data=region, color='#FFCB74', linewidth=2, edgecolor='#F6F6F6')

# annotating the values on the plot
bbox_args = dict(boxstyle = 'round', fc = '1')
for p in ax.patches:
    width = p.get_width()
    plt.text(p.get_width(), p.get_y() + 0.5 * p.get_height(), '{:1.0f}'.format(width), 
             ha = 'center', 
             va = 'center', 
             color = 'black', 
             bbox = bbox_args, 
             fontsize = 15)

# formatting the graph
plt.title('Total Orders by Region', fontsize = 18)
plt.tick_params(left=False, bottom=False, labelbottom=False)
plt.xlabel('Orders')
plt.ylabel(None)

plt.show()

# %% [markdown]
# ### Total Sales by Category & Sub Category

# %% [markdown]
# We'll now find the total sales by Category and further group it down to each Sub Category within it. We'll assign two values within the index parameter of the .pivot_table() function to achieve the results.

# %%
category_sales = pd.pivot_table(data=df, index=['Category', 'Sub Category'], values='Sales', 
               aggfunc='sum').reset_index().sort_values(['Category', 'Sales'], ascending=False)
category_sales
# Out:
#              Category        Sub Category          Sales
# 22             Snacks             Noodles  493875.193029
# 20             Snacks          Chocolates  308514.747989
# 21             Snacks             Cookies  280157.445040
# 18       Oil & Masala             Masalas  456415.514745
# 17       Oil & Masala   Edible Oil & Ghee  253193.908847
# 19       Oil & Masala              Spices  251136.176944
# 14   Fruits & Veggies    Fresh Vegetables  403694.479893
# 13   Fruits & Veggies        Fresh Fruits  236229.230563
# 15   Fruits & Veggies      Organic Fruits  218535.284182
# 16   Fruits & Veggies  Organic Vegetables  200027.445040
# 10        Food Grains       Dals & Pulses  392738.104558
# 12        Food Grains                Rice  234938.284182
# 9         Food Grains        Atta & Flour  233186.713137
# 11        Food Grains     Organic Staples  229472.801609
# 8   Eggs, Meat & Fish              Mutton  450786.514745
# 7   Eggs, Meat & Fish                Fish  235710.284182
# 6   Eggs, Meat & Fish                Eggs  224900.337802
# 5   Eggs, Meat & Fish             Chicken  209462.391421
# 4           Beverages         Soft Drinks  600418.407507
# 3           Beverages       Health Drinks  413822.372654
# 1              Bakery       Breads & Buns  495479.675603
# 2              Bakery               Cakes  307082.426273
# 0              Bakery            Biscuits  264802.284182

# %%
# fixing the graph size
plt.rcParams['figure.figsize'] = (15,15)

# setting the background color
ax = plt.axes()
ax.set_facecolor('#2F2F2F')

# plotting a bar plot with Category as the distinguishing parameter
sns.barplot(y='Sub Category', x='Sales', data=category_sales, hue='Category', linewidth=1, edgecolor='#F6F6F6')

# annotating the values on the plot
bbox_args = dict(boxstyle = 'round', fc = '1')
for p in ax.patches:
    width = p.get_width()
    plt.text(p.get_width(), p.get_y() + 0.5 * p.get_height(), '{:1.0f}'.format(width), 
             ha = 'center', 
             va = 'center', 
             color = 'black', 
             bbox = bbox_args, 
             fontsize = 15)

# formatting the graph
plt.title('Sales by Category & Sub Category', fontsize = 18)
plt.ylabel(None)
plt.tick_params(left=False, bottom=False, labelbottom=False)
plt.show()
# Out:
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values

# %% [markdown]
# The hue parameter of the barplot() helped us distinguish the Sub Categories by the Category to which they belong to.

# %% [markdown]
# ### Profit Margin by Sub Category

# %% [markdown]
# The profit margin can be calculated by dividing the profit by the total sales. As this needs to be computed for each sub category, we did not compute this on the original dataset. First let us group the data by sub category and then compute the profit margin.

# %%
profit = pd.pivot_table(data=df, index='Sub Category', values=['Sales', 'Profit'], aggfunc='sum').reset_index()
profit
# Out:
#           Sub Category     Profit          Sales
# 0         Atta & Flour   51250.02  233186.713137
# 1             Biscuits   59434.85  264802.284182
# 2        Breads & Buns  122843.86  495479.675603
# 3                Cakes   73253.76  307082.426273
# 4              Chicken   48606.37  209462.391421
# 5           Chocolates   78249.71  308514.747989
# 6              Cookies   71126.94  280157.445040
# 7        Dals & Pulses   93798.40  392738.104558
# 8    Edible Oil & Ghee   64248.07  253193.908847
# 9                 Eggs   52972.40  224900.337802
# 10                Fish   62487.22  235710.284182
# 11        Fresh Fruits   56444.76  236229.230563
# 12    Fresh Vegetables   99180.15  403694.479893
# 13       Health Drinks  100966.51  413822.372654
# 14             Masalas  113043.53  456415.514745
# 15              Mutton  108090.94  450786.514745
# 16             Noodles  124174.07  493875.193029
# 17      Organic Fruits   54473.33  218535.284182
# 18     Organic Staples   59819.20  229472.801609
# 19  Organic Vegetables   45311.71  200027.445040
# 20                Rice   58546.62  234938.284182
# 21         Soft Drinks  141495.15  600418.407507
# 22              Spices   61123.44  251136.176944

# %%
profit['Profit Margin'] = round((profit['Profit']/profit['Sales']) * 100,2)
profit.sort_values(by='Profit Margin', ascending=False, inplace = True)
profit
# Out:
#           Sub Category     Profit          Sales  Profit Margin
# 10                Fish   62487.22  235710.284182          26.51
# 18     Organic Staples   59819.20  229472.801609          26.07
# 6              Cookies   71126.94  280157.445040          25.39
# 8    Edible Oil & Ghee   64248.07  253193.908847          25.38
# 5           Chocolates   78249.71  308514.747989          25.36
# 16             Noodles  124174.07  493875.193029          25.14
# 17      Organic Fruits   54473.33  218535.284182          24.93
# 20                Rice   58546.62  234938.284182          24.92
# 2        Breads & Buns  122843.86  495479.675603          24.79
# 14             Masalas  113043.53  456415.514745          24.77
# 12    Fresh Vegetables   99180.15  403694.479893          24.57
# 13       Health Drinks  100966.51  413822.372654          24.40
# 22              Spices   61123.44  251136.176944          24.34
# 15              Mutton  108090.94  450786.514745          23.98
# 11        Fresh Fruits   56444.76  236229.230563          23.89
# 7        Dals & Pulses   93798.40  392738.104558          23.88
# 3                Cakes   73253.76  307082.426273          23.85
# 21         Soft Drinks  141495.15  600418.407507          23.57
# 9                 Eggs   52972.40  224900.337802          23.55
# 4              Chicken   48606.37  209462.391421          23.21
# 19  Organic Vegetables   45311.71  200027.445040          22.65
# 1             Biscuits   59434.85  264802.284182          22.44
# 0         Atta & Flour   51250.02  233186.713137          21.98

# %%
# fixing the graph size
plt.rcParams['figure.figsize'] = (15,20)

# setting up the background color
ax = plt.axes()
ax.set_facecolor('#2F2F2F')

# plotting a bar graph
sns.barplot(y='Sub Category', x='Profit Margin', data=profit, color='#FFCB74', linewidth=2, edgecolor='#F6F6F6')

# annotating the values on the graph
bbox_args = dict(boxstyle = 'round', fc = '1')
for p in ax.patches:
    width = p.get_width()
    plt.text(p.get_width(), p.get_y() + 0.5 * p.get_height(), '{:1.2f}%'.format(width), 
             ha = 'center', 
             va = 'center', 
             color = 'black', 
             bbox = bbox_args, 
             fontsize = 15)

# formatting the graph
plt.title('Profit Margin by Sub Category', fontsize = 18)
plt.tick_params(left=False, bottom=False, labelbottom=False)
plt.ylabel(None)

plt.show()

# %% [markdown]
# ### How much did the company lose by giving discounts?

# %% [markdown]
# To find the amount that the company lost by giving discounts, we need to find the original price. We've the sold price of the product in the dataset. We also have the discount percentage for that product.
#
# The formula to find the original price is (Sold Price * 100)/100 - (Discount Percent * 100)

# %%
df['Original Price'] = round((df['Sales'])*100/(100-(df['Discount']*100)),2)
df['Discounted Amount'] = df['Original Price'] - df['Sales']
df.head(2)
# Out:
#   Order ID Customer Name      Category Sub Category         City Order Date  \
# 1     OD30      Customer  Oil & Masala      Masalas  Kanyakumari  9/17/2016
# 2     OD31        Ramesh     Beverages  Soft Drinks   Dharmapuri  9/17/2016
#
#   Region        Sales  Discount  Profit       State Order Year  \
# 1   East   989.000000      0.17   69.23  Tamil Nadu       2016
# 2   East  1498.946381      0.24  166.05  Tamil Nadu       2016
#
#    Original Price  Discounted Amount
# 1         1191.57         202.570000
# 2         1972.30         473.353619

# %%
discounts = pd.pivot_table(data=df, index='Sub Category',
               values='Discounted Amount', 
               aggfunc='sum').reset_index().sort_values(by='Discounted Amount', ascending=False)
discounts
# Out:
#           Sub Category  Discounted Amount
# 21         Soft Drinks      182352.362493
# 2        Breads & Buns      149817.854397
# 16             Noodles      144181.056971
# 14             Masalas      140050.795255
# 15              Mutton      135027.195255
# 13       Health Drinks      130188.737346
# 12    Fresh Vegetables      126198.170107
# 7        Dals & Pulses      117604.845442
# 3                Cakes       93971.743727
# 5           Chocolates       89506.642011
# 6              Cookies       84826.074960
# 1             Biscuits       79761.695818
# 8    Edible Oil & Ghee       78025.641153
# 22              Spices       74905.173056
# 10                Fish       73876.775818
# 11        Fresh Fruits       73515.569437
# 18     Organic Staples       73008.448391
# 0         Atta & Flour       71506.296863
# 20                Rice       70709.295818
# 9                 Eggs       68519.722198
# 17      Organic Fruits       66435.795818
# 19  Organic Vegetables       63097.734960
# 4              Chicken       61356.408579

# %%
# fixing the graph size
plt.rcParams['figure.figsize'] = (15,20)

# setting up the background color
ax = plt.axes()
ax.set_facecolor('#2F2F2F')

# plotting a bar graph
sns.barplot(y='Sub Category', x='Discounted Amount', data=discounts, color='#FFCB74', linewidth=2, edgecolor='#F6F6F6')

# annotating the values on the bar graph
bbox_args = dict(boxstyle = 'round', fc = '1')
for p in ax.patches:
    width = p.get_width()
    plt.text(p.get_width(), p.get_y() + 0.5 * p.get_height(), '{:1.0f}'.format(width), 
             ha = 'center', 
             va = 'center', 
             color = 'black', 
             bbox = bbox_args, 
             fontsize = 15)

#formatting the graph
plt.title('Discounted Amount by Sub Category', fontsize = 18)
plt.tick_params(left=False, bottom=False, labelbottom=False)
plt.ylabel(None)
plt.show()

# %% [markdown]
# ### Total Sales & Orders by Year

# %%
year_performance = pd.pivot_table(data=df, index='Order Year', values=['Order ID', 'Sales', 'Profit'], 
               aggfunc={'Order ID':'count', 'Sales':'sum', 'Profit':'sum'}).reset_index()
year_performance
# Out:
#   Order Year  Order ID     Profit         Sales
# 0       2015       990  360708.22  1.476879e+06
# 1       2016       997  370228.85  1.514474e+06
# 2       2017      1262  452612.88  1.896012e+06
# 3       2018      1658  617391.06  2.507215e+06

# %%
# setting up the graph size
plt.rcParams['figure.figsize'] = (12,8)

# setting up the background color
ax = plt.axes()
ax.set_facecolor('#2F2F2F')

# plotting a bar graph
ax1 = sns.barplot(x='Order Year', y='Sales', data=year_performance, color='#FFCB74', linewidth=2, edgecolor='#F6F6F6')
plt.tick_params(left=False, labelleft=False)

# annotating the values on the graph
bbox_args = dict(boxstyle = 'round', fc = '1')
for p in ax.patches:
    height = p.get_height()
    plt.text(p.get_x() + 0.5 * p.get_width(), p.get_height(), '{:1.0f}'.format(height), 
             ha = 'center', 
             va = 'center', 
             color = 'black', 
             bbox = bbox_args, 
             fontsize = 15)

# setting up the dual axis
ax2 = ax1.twinx()

# plotting a line graph on the secondary axis
sns.lineplot(x='Order Year', y='Profit', data=year_performance, linewidth=4, marker='o')

# formatting the graph
plt.title('Year Wise Performance - Sales & Profit', fontsize = 18)
plt.ylabel(None)
plt.legend(['Profit'], loc='upper left')
plt.tick_params(right=False, labelright=False)
plt.show()

# %% [markdown]
# ## Answering the Questions

# %% [markdown]
# ### 1) Who are the most loyal customers?
# Note: Customers who placed more than 20 orders every year

# %% [markdown]
# We'll pivot the values by using the .pivot_table() function and then filter it with the above condition.

# %%
customers = pd.pivot_table(data=df, index='Customer Name', columns='Order Year', 
               values='Order ID', aggfunc='count')
customers = customers[(customers['2015']>18) & (customers['2016']>18) & (customers['2017']>18) & (customers['2018']>18)]
customers
# Out:
# Order Year     2015  2016  2017  2018
# Customer Name
# Customer        204   207   264   319
# Haseena          19    23    22    25
# Veena            19    22    25    24

# %% [markdown]
# **Answer: No customer with the records of order more than 20 from 2015 to 2018, But Haseena and Veena is the most closest to become the most loyal customer**

# %% [markdown]
# ### 2) What is the rank of the sub category in 2018, that ranked the fifth in 2016?
# Note: Take sales as the parameter to compute rank

# %% [markdown]
# We'll first pivot the data and then apply the rank() function.

# %%
sales_sc = pd.pivot_table(data=df, index='Sub Category', columns = 'Order Year', values='Sales', aggfunc='sum').reset_index()
sales_sc['Rank_2016'] = sales_sc['2016'].rank(method='max', ascending=False)
sales_sc['Rank_2018'] = sales_sc['2018'].rank(method='max', ascending=False)
sales_sc.sort_values(by='Rank_2016')
# Out:
# Order Year        Sub Category           2015           2016           2017  \
# 21                 Soft Drinks  117443.088472  111754.356568  147691.195710
# 2                Breads & Buns  113180.088472  109282.410188  115160.088472
# 12            Fresh Vegetables   82817.517426   93452.356568  102346.463807
# 13               Health Drinks   76586.517426   92358.356568  104173.356568
# 16                     Noodles  101025.195710   90000.517426  157669.659517
# 14                     Masalas   79920.195710   86196.463807  126767.142091
# 7                Dals & Pulses   68119.731903   80070.624665  114632.034853
# 15                      Mutton  101310.356568   71450.410188  114381.981233
# 1                     Biscuits   48830.624665   67739.624665   64735.731903
# 3                        Cakes   71894.517426   67589.302949   57768.517426
# 5                   Chocolates   73334.463807   63046.517426   61267.624665
# 11                Fresh Fruits   47270.571046   59468.517426   46006.678284
# 20                        Rice   41555.517426   51030.731903   66650.463807
# 0                 Atta & Flour   30957.839142   49338.785523   72108.624665
# 6                      Cookies   55538.785523   48902.785523   74683.517426
# 8            Edible Oil & Ghee   43963.678284   48777.785523   76821.088472
# 10                        Fish   54694.517426   47967.946381   53181.410188
# 22                      Spices   58680.517426   47749.571046   60514.463807
# 9                         Eggs   36455.731903   47284.517426   60269.517426
# 19          Organic Vegetables   48978.356568   47049.731903   42732.678284
# 18             Organic Staples   40375.571046   45016.571046   59948.463807
# 17              Organic Fruits   33946.678284   44611.624665   56347.624665
# 4                      Chicken   49998.731903   44334.678284   60153.517426
#
# Order Year           2018  Rank_2016  Rank_2018
# 21          223529.766756        1.0        1.0
# 2           157857.088472        2.0        4.0
# 12          125078.142091        3.0        8.0
# 13          140704.142091        4.0        6.0
# 16          145179.820375        5.0        5.0
# 14          163531.713137        6.0        3.0
# 7           129915.713137        7.0        7.0
# 15          163643.766756        8.0        2.0
# 1            83496.302949        9.0       16.0
# 3           109830.088472       10.0       10.0
# 5           110866.142091       11.0        9.0
# 11           83483.463807       12.0       17.0
# 20           75701.571046       13.0       21.0
# 0            80781.463807       14.0       19.0
# 6           101032.356568       15.0       11.0
# 8            83631.356568       16.0       14.0
# 10           79866.410188       17.0       20.0
# 22           84191.624665       18.0       12.0
# 9            80890.571046       19.0       18.0
# 19           61266.678284       20.0       22.0
# 18           84132.195710       21.0       13.0
# 17           83629.356568       22.0       15.0
# 4            54975.463807       23.0       23.0

# %% [markdown]
# **Answer: Noodles is in the 5th rank both in 2016 and 2018.**

# %% [markdown]
# ### 3) Which Category is among the top 5 position in Sales, all the years?

# %%
var1 = pd.pivot_table(data=df, index='Category', columns = 'month', values='Sales', aggfunc='sum').reset_index()
var1
# Out:
# month           Category             1             2             3  \
# 0                 Bakery  37879.731903  21245.892761  81495.195710
# 1              Beverages  54036.731903  26400.946381  72718.624665
# 2      Eggs, Meat & Fish  41809.624665  31684.731903  90144.410188
# 3            Food Grains  32489.839142  32213.678284  53358.624665
# 4       Fruits & Veggies  47830.785523  39541.731903  64972.356568
# 5           Oil & Masala  39826.678284  30343.785523  71767.249330
# 6                 Snacks  53905.624665  42752.571046  85690.410188
#
# month             4             5             6             7             8  \
# 0      61411.624665  68542.785523  82631.356568  90195.571046  81542.142091
# 1      84402.624665  82787.302949  67702.249330  75557.249330  67468.624665
# 2      50673.463807  77874.302949  76747.410188  77445.463807  69910.142091
# 3      55455.785523  87438.463807  64067.410188  85642.356568  87829.463807
# 4      74126.410188  67313.410188  72858.302949  79659.463807  71588.731903
# 5      73035.195710  99133.463807  57511.410188  74324.678284  42939.517426
# 6      75419.410188  67884.410188  83891.571046  72638.356568  62178.785523
#
# month              9             10             11             12
# 0      141280.873995   84121.463807  168322.873995  148694.873995
# 1      126890.034853   86855.571046  149595.356568  119825.463807
# 2      169211.034853  105524.142091  147738.088472  182096.713137
# 3      172579.605898  103206.981233  159269.981233  156783.713137
# 4      139580.873995   78216.571046  155276.927614  167520.873995
# 5      142021.034853   78161.249330  142305.302949  109376.034853
# 6      156540.981233   79969.624665  159808.766756  141866.873995

# %%
var2 = pd.pivot_table(data=df, index='Sub Category', columns = 'month', values='Sales', aggfunc='sum').reset_index()
var2
# Out:
# month        Sub Category             1             2             3  \
# 0            Atta & Flour  11650.000000   4418.000000   7643.946381
# 1                Biscuits  14535.785523   5198.000000  19625.839142
# 2           Breads & Buns  11932.946381  13451.946381  31394.678284
# 3                   Cakes  11411.000000   2595.946381  30474.678284
# 4                 Chicken   7584.892761   6049.000000  13291.946381
# 5              Chocolates  11387.892761  14280.892761  32251.785523
# 6                 Cookies  17498.946381   6845.946381  19981.785523
# 7           Dals & Pulses   9408.946381   8407.892761  16235.892761
# 8       Edible Oil & Ghee   7897.892761  11081.892761  19331.785523
# 9                    Eggs   3733.946381   2255.000000  24713.839142
# 10                   Fish  10219.892761   9931.785523  13629.000000
# 11           Fresh Fruits   3950.000000   6786.946381   8294.946381
# 12       Fresh Vegetables  29087.839142  14424.000000  31327.624665
# 13          Health Drinks  19226.892761   8489.000000  25071.839142
# 14                Masalas  22450.892761  12129.946381  39200.624665
# 15                 Mutton  20270.892761  13448.946381  38509.624665
# 16                Noodles  25018.785523  21625.731903  33456.839142
# 17         Organic Fruits   8947.000000   9380.892761  12630.892761
# 18        Organic Staples   4747.946381   7782.946381  14358.892761
# 19     Organic Vegetables   5845.946381   8949.892761  12718.892761
# 20                   Rice   6682.946381  11604.839142  15119.892761
# 21            Soft Drinks  34809.839142  17911.946381  47646.785523
# 22                 Spices   9477.892761   7131.946381  13234.839142
#
# month             4             5             6             7             8  \
# 0      10449.000000  21103.839142  19842.839142  16948.839142  10987.000000
# 1      12735.839142  22908.000000  17926.946381  18265.946381  13763.839142
# 2      27868.892761  27839.946381  38864.678284  44511.785523  39092.731903
# 3      20806.892761  17794.839142  25839.731903  27417.839142  28685.571046
# 4       7857.000000  19702.839142  12043.839142  19543.946381  14571.731903
# 5      26013.785523  11850.839142  25402.946381  20628.785523   7247.946381
# 6      19431.839142  16935.946381  17008.839142  17784.000000  27826.946381
# 7      22174.892761  30261.839142  20430.839142  39753.839142  31441.892761
# 8      28890.731903  28659.785523  14770.892761  18284.839142   9059.892761
# 9      13886.785523  19292.785523  10931.892761  10508.946381  21464.839142
# 10     17294.785523   8539.946381  16119.892761  26538.731903   8475.892761
# 11     28836.892761  20687.731903  13522.839142  15556.892761  13414.946381
# 12     20368.785523  24790.785523  34986.678284  26451.892761  25834.946381
# 13     34073.785523  33385.678284  33698.624665  27687.731903  34153.785523
# 14     30970.624665  42682.785523  23712.731903  36857.892761  20437.731903
# 15     11634.892761  30338.731903  37651.785523  20853.839142  25397.678284
# 16     29973.785523  39097.624665  41479.785523  34225.571046  27103.892761
# 17     10250.946381  13539.946381  16753.839142  20733.785523  14730.946381
# 18     17263.892761  20350.839142  14617.892761  14971.785523  20637.678284
# 19     14669.785523   8294.946381   7594.946381  16916.892761  17607.892761
# 20      5568.000000  15721.946381   9175.839142  13967.892761  24762.892761
# 21     50328.839142  49401.624665  34003.624665  47869.517426  33314.839142
# 22     13173.839142  27790.892761  19027.785523  19181.946381  13441.892761
#
# month             9            10            11            12
# 0      40116.892761  17922.839142  36456.785523  35646.731903
# 1      32579.678284  24004.785523  37846.785523  45410.839142
# 2      73422.517426  44136.785523  81442.410188  61520.356568
# 3      35278.678284  15979.892761  49033.678284  41763.678284
# 4      26369.892761  13327.785523  30329.839142  38789.678284
# 5      35872.892761  24646.839142  43736.731903  55193.410188
# 6      42257.678284  16958.892761  40125.839142  37500.785523
# 7      68069.249330  30492.731903  52713.678284  63346.410188
# 8      33144.785523  11406.892761  44065.785523  26598.731903
# 9      30570.731903  26467.892761  22851.946381  38221.731903
# 10     40113.839142  14411.892761  36734.678284  33699.946381
# 11     38002.678284  12407.892761  28361.785523  46405.678284
# 12     37532.785523  43916.785523  53488.785523  61483.571046
# 13     42464.624665  46679.839142  58123.892761  50766.678284
# 14     64710.517426  51084.571046  66418.678284  45758.517426
# 15     72156.571046  51316.571046  57821.624665  71385.356568
# 16     78410.410188  38363.892761  75946.195710  49172.678284
# 17     35837.571046  12929.946381  31851.785523  30947.731903
# 18     27312.678284  29934.731903  35693.731903  21799.785523
# 19     28207.839142   8961.946381  41574.571046  28683.892761
# 20     37080.785523  24856.678284  34405.785523  35990.785523
# 21     84425.410188  40175.731903  91471.463807  69058.785523
# 22     44165.731903  15669.785523  31820.839142  37018.785523

# %%
var2.max()
# Out:
# month
# Sub Category          Spices
# 1               34809.839142
# 2               21625.731903
# 3               47646.785523
# 4               50328.839142
# 5               49401.624665
# 6               41479.785523
# 7               47869.517426
# 8               39092.731903
# 9               84425.410188
# 10              51316.571046
# 11              91471.463807
# 12              71385.356568
# dtype: object

# %%
sales_c = pd.pivot_table(data=df, index='Category', columns = 'Order Year', values='Sales', aggfunc='sum').reset_index()
sales_c['2015_Rank'] = sales_c['2015'].rank(method='max', ascending=False)
sales_c['2016_Rank'] = sales_c['2016'].rank(method='max', ascending=False)
sales_c['2017_Rank'] = sales_c['2017'].rank(method='max', ascending=False)
sales_c['2018_Rank'] = sales_c['2018'].rank(method='max', ascending=False)
sales_c
# Out:
# Order Year           Category           2015           2016           2017  \
# 0                      Bakery  233905.230563  244611.337802  237664.337802
# 1                   Beverages  194029.605898  204112.713137  251864.552279
# 2           Eggs, Meat & Fish  242459.337802  211037.552279  287986.426273
# 3                 Food Grains  181008.659517  225456.713137  313339.587131
# 4            Fruits & Veggies  213013.123324  244582.230563  247433.445040
# 5                Oil & Masala  182564.391421  182723.820375  264102.694370
# 6                      Snacks  229898.445040  201949.820375  293620.801609
#
# Order Year           2018  2015_Rank  2016_Rank  2017_Rank  2018_Rank
# 0           351183.479893        2.0        1.0        7.0        6.0
# 1           364233.908847        5.0        5.0        5.0        3.0
# 2           379376.211796        1.0        4.0        3.0        1.0
# 3           370530.943700        7.0        3.0        1.0        2.0
# 4           353457.640751        4.0        2.0        6.0        5.0
# 5           331354.694370        6.0        7.0        4.0        7.0
# 6           357078.319035        3.0        6.0        2.0        4.0

# %%
sales_c[(sales_c['2015_Rank'] <=5) & (sales_c['2016_Rank'] <=5) & (sales_c['2017_Rank'] <=5) & (sales_c['2018_Rank'] <=5)]
# Out:
# Order Year           Category           2015           2016           2017  \
# 1                   Beverages  194029.605898  204112.713137  251864.552279
# 2           Eggs, Meat & Fish  242459.337802  211037.552279  287986.426273
#
# Order Year           2018  2015_Rank  2016_Rank  2017_Rank  2018_Rank
# 1           364233.908847        5.0        5.0        5.0        3.0
# 2           379376.211796        1.0        4.0        3.0        1.0

# %% [markdown]
# **Answer: Only the Eggs, Meat & Fish Category is consistent in the sales across years.**

# %% [markdown]
# ### 4) Did the region with least Sales/Order record the least Profit/Order?

# %%
sales_orders_region = pd.pivot_table(data=df, index='Region', values=['Order ID', 'Sales', 'Profit'], 
               aggfunc = {'Order ID':'count', 'Sales':'sum', 'Profit':'sum'}).reset_index().sort_values(by='Sales', ascending=False)
sales_orders_region['Sales Per Order'] = sales_orders_region['Sales']/sales_orders_region['Order ID']
sales_orders_region['Profit Per Order'] = sales_orders_region['Profit']/sales_orders_region['Order ID']
sales_orders_region[['Region', 'Sales Per Order', 'Profit Per Order']]
# Out:
#     Region  Sales Per Order  Profit Per Order
# 3     West      1510.211077        361.130937
# 1     East      1495.989712        367.799379
# 0  Central      1505.089402        362.657207
# 2    South      1522.505254        383.523060

# %% [markdown]
# **Answer: No, East region has the least Sales/Order but the least Profit/Order is in the West Region.**

# %% [markdown]
# ### 5) Which city has the more Chicken & Mutton lovers?

# %%
mutton = df[(df['Sub Category'] == 'Mutton') | (df['Sub Category'] == 'Chicken')]

mutton_pivot = pd.pivot_table(data=mutton, index='City', 
                               values='Order ID', aggfunc='count').sort_values(by='Order ID', ascending=False)
mutton_pivot.head(1)
# Out:
#       Order ID
# City
# Bodi        83

# %% [markdown]
# **Answer: Customers from Bodi have ordered chicken and mutton more times than others.**

# %% [markdown]
# ### 6) Name three cities which have the highest Sales/Customers for Cakes and Chocolates.

# %%
7chocolate_cakes = df[(df['Sub Category'] == 'Cakes') | (df['Sub Category'] == 'Chocolates')]

avg_sales_per_customer = pd.pivot_table(data=chocolate_cakes, index='City', values=['Sales', 'Customer Name'], 
               aggfunc = {'Customer Name':'count', 'Sales':'sum'}).reset_index()
avg_sales_per_customer['Sales Per Customer'] = round(avg_sales_per_customer['Sales']/avg_sales_per_customer['Customer Name'], 2)
avg_sales_per_customer[['City','Sales Per Customer']].sort_values(by='Sales Per Customer', ascending=False).head(3)
# Out:
#               City  Sales Per Customer
# 20          Trichy             1779.06
# 15  Ramanadhapuram             1697.00
# 2       Coimbatore             1657.07

# %% [markdown]
# **Answer: Trichy, Ramanadhapuram and Coimbatore are the three cities that have the highest Sales/Customer for Cakes and Chocolate sub categories.**

# %% [markdown]
# #Assignment

# %%
df.sample(2)
# Out:
#      Order ID Customer Name          Category  Sub Category  City Order Date  \
# 7441   OD6103      Customer  Fruits & Veggies  Fresh Fruits  Bodi 2016-12-27
# 3104   OD3451         Surya         Beverages   Soft Drinks  Bodi 2018-11-12
#
#        Region        Sales  Discount  Profit       State  month
# 7441    South  1498.946381      0.26  187.59  Tamil Nadu     12
# 3104  Central  1185.000000      0.21  414.75  Tamil Nadu     11

# %%
df['Region'].unique()
# Out:
# array(['East', 'Central', 'West', 'South'], dtype=object)

# %%
#1
#pola bulanan terhadap hasil penjualan di setiap region supermarket

var1 = df.groupby(["Region","month"])["Sales"].sum().reset_index(name="count")
Central = var1[var1["Region"]=="Central"]
West = var1[var1["Region"]=="West"]
East = var1[var1["Region"]=="East"]
South = var1[var1["Region"]=="South"]

# %%
plt.subplot(4, 1, 1)
sns.barplot(x="Region", y="count" ,hue="month", data=Central)
plt.subplot(4, 1, 2)
sns.barplot(x="Region", y="count" ,hue="month", data=West)
plt.subplot(4, 1, 3)
sns.barplot(x="Region", y="count" ,hue="month", data=East)
plt.subplot(4, 1, 4)
sns.barplot(x="Region", y="count" ,hue="month", data=South)

# %%
#2

plt.figure(figsize=(15,15))

plt.subplot(2, 1, 1)
sns.barplot(x="month", y="count", data=var1)
plt.subplot(2, 1, 2)
sns.barplot(x="month", y="Profit", data=df)

# %%
east = pd.pivot_table(data=df, index='Region', columns='month', 
               values='Sales', aggfunc='sum')
#east = east[east["Region"]]
east
# Out:
# month              1             2              3              4   \
# Region
# Central  99937.410188  54529.410188  132832.873995   90352.302949
# East     65128.517426  57611.571046  118135.088472  145984.195710
# South    58420.785523  43702.624665  105680.302949   82214.517426
# West     84292.302949  68339.731903  163498.605898  155973.498660
#
# month               5              6              7              8   \
# Region
# Central  133549.820375  113207.463807  120429.034853   90424.356568
# East     133808.981233  153753.284182  198974.820375  121859.195710
# South    111506.517426   84226.410188   82667.517426   85791.195710
# West     172108.820375  154222.552279  153391.766756  185382.659517
#
# month               9              10             11             12
# Region
# Central  225218.552279  147052.927614  278972.176944  232305.766756
# East     355549.533512  140332.873995  290489.445040  315750.069705
# South    136621.034853   98312.463807  186168.927614  133556.873995
# West     330715.319035  230357.337802  326686.747989  344551.836461

# %%
#3
